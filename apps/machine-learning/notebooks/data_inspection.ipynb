# %%
import pandas as pd

# Load the Parquet file

train_file_path = "../data/train/train_batch_0.parquet"
df = pd.read_parquet(train_file_path)



df.head()
# Out:
#    region  averageTier  averageDivision  \
# 0       0            0                0
# 1       0            0                0
# 2       0            0                0
# 3       0            0                0
# 4       0            0                0
#
#                                         champion_ids  gameVersionMajorPatch  \
# 0      [36, 5, 61, 147, 235, 163, 427, 910, 21, 111]                     14
# 1  [777, 106, 246, 110, 350, 150, 120, 901, 81, 111]                     14
# 2     [875, 59, 103, 136, 111, 150, 5, 61, 202, 497]                     14
# 3      [24, 56, 61, 202, 89, 901, 876, 166, 81, 555]                     14
# 4         [92, 28, 42, 51, 25, 80, 234, 901, 30, 89]                     14
#
#    gameVersionMinorPatch  win_prediction  game_duration  gold_at_15_TOP_100  \
# 0                     17               0           1898                5978
# 1                     17               1           1963                4100
# 2                     18               0           1506                4162
# 3                     18               0           1607                6742
# 4                     17               1           1766                5086
#
#    gold_at_15_TOP_200  gold_at_15_JUNGLE_100  gold_at_15_JUNGLE_200  \
# 0                5001                   5848                   5051
# 1                6376                   5364                   5091
# 2                7202                   5022                   6534
# 3                3743                   6713                   6114
# 4                5832                   7475                   7815
#
#    gold_at_15_MIDDLE_100  gold_at_15_MIDDLE_200  gold_at_15_BOTTOM_100  \
# 0                   6382                   5468                   4519
# 1                   5402                   7148                   5745
# 2                   4996                   6441                   4927
# 3                   6028                   6781                   6135
# 4                   6642                   5497                   7665
#
#    gold_at_15_BOTTOM_200  gold_at_15_UTILITY_100  gold_at_15_UTILITY_200
# 0                   6462                    3937                    4633
# 1                   4052                    3698                    3957
# 2                   4951                    3179                    4514
# 3                   7318                    4611                    4086
# 4                   5289                    4397                    3666
